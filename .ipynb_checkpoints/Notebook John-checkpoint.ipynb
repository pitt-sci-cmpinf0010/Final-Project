# %%
import pandas as pd
data = pd.read_csv("https://data.wprdc.org/dataset/c6265ffb-c86e-4a2c-870b-1aaa0772c449/resource/14abb000-d066-4728-8ffa-227883d6c331/download/wage-or-salary-income-in-the-past-12-months-for-households.csv",
                  index_col='Id')

data.head(10)
# Out:
#          Neighborhood  Estimate; Total:  Margin of Error; Total:  \
# Id
# 1    Allegheny Center             733.0               103.000000
# 2      Allegheny West             150.0                46.000000
# 3           Allentown            1138.0               152.751432
# 4           Arlington             685.0               105.366029
# 5   Arlington Heights             170.0                69.000000
# 6          Banksville            2002.0               224.986666
# 7   Bedford Dwellings             684.0                63.000000
# 8           Beechview            3557.0               270.051847
# 9         Beltzhoover             869.0               146.594679
# 10         Bloomfield            4640.0               215.506380
#
#     Estimate; Total: - With wage or salary income  \
# Id
# 1                                           462.0
# 2                                           120.0
# 3                                           772.0
# 4                                           566.0
# 5                                            96.0
# 6                                          1596.0
# 7                                           294.0
# 8                                          2654.0
# 9                                           586.0
# 10                                         3789.0
#
#     Margin of Error; Total: - With wage or salary income  \
# Id
# 1                                           94.000000
# 2                                           40.000000
# 3                                          146.771932
# 4                                          104.589674
# 5                                           58.000000
# 6                                          226.477372
# 7                                           69.000000
# 8                                          249.649755
# 9                                          117.187883
# 10                                         223.385317
#
#     Estimate; Total: - No wage or salary income  \
# Id
# 1                                         271.0
# 2                                          30.0
# 3                                         366.0
# 4                                         119.0
# 5                                          74.0
# 6                                         406.0
# 7                                         390.0
# 8                                         903.0
# 9                                         283.0
# 10                                        851.0
#
#     Margin of Error; Total: - No wage or salary income
# Id
# 1                                           87.000000
# 2                                           26.000000
# 3                                          109.389213
# 4                                           44.452222
# 5                                           52.000000
# 6                                          145.168867
# 7                                           77.000000
# 8                                          162.154248
# 9                                          107.712581
# 10                                         117.388245

# %% [markdown]
# So I have data about how many people are living in a neighborhood "With wage or salary income" and with "No wage or salary income".
# My metric is the percentage of the population in a neighborhood that has an income.
# I'm going to make a dataframe that holds values equivalent to the percentage of people with wage/salary income out of the whole population of that area.

# %%
percs = []
i = 0
for item in data.iterrows():
    percent = item[1][3]/item[1][1]
    print(percent)
    percs[i]=percent
    i+=1
# Out:
# 0.6302864938608458
# 0.8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-bea5b6c6725c> in <module>
#       4     percent = item[1][3]/item[1][1]
#       5     print(percent)
# ----> 6     percs[i]=percent
#       7     i+=1
#
# IndexError: list assignment index out of range
